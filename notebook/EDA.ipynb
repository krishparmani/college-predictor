# %%
import pandas as pd

df = pd.read_csv("../dataset/processed/2023-2024.csv")

df.head()
# Out:
#   academic_year  college_code                                 college_name  \
# 0     2023-2024          1002  Government College of Engineering, Amravati
# 1     2023-2024          1002  Government College of Engineering, Amravati
# 2     2023-2024          1002  Government College of Engineering, Amravati
# 3     2023-2024          1002  Government College of Engineering, Amravati
# 4     2023-2024          1002  Government College of Engineering, Amravati
#
#    branch_code        branch_name                 status          section  \
# 0    100219110  Civil Engineering  Government Autonomous  Home University
# 1    100219110  Civil Engineering  Government Autonomous  Home University
# 2    100219110  Civil Engineering  Government Autonomous  Home University
# 3    100219110  Civil Engineering  Government Autonomous  Home University
# 4    100219110  Civil Engineering  Government Autonomous  Home University
#
#   category stage  merit_rank  percentile
# ...

# %%
df.shape
# Out:
# (23507, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23507 entries, 0 to 23506
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   academic_year  23507 non-null  object
#  1   college_code   23507 non-null  int64
#  2   college_name   23507 non-null  object
#  3   branch_code    23507 non-null  int64
#  4   branch_name    23507 non-null  object
#  5   status         23507 non-null  object
#  6   section        23507 non-null  object
#  7   category       23507 non-null  object
#  8   stage          23507 non-null  object
#  9   merit_rank     23012 non-null  float64
#  10  percentile     23012 non-null  float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 2.0+ MB

# %%
df.isnull().sum()
# Out:
# academic_year      0
# college_code       0
# college_name       0
# branch_code        0
# branch_name        0
# status             0
# section            0
# category           0
# stage              0
# merit_rank       495
# percentile       495
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["academic_year"].value_counts()
# Out:
# academic_year
# 2023-2024    23507
# Name: count, dtype: int64

# %%
df["section"].value_counts()
# Out:
# section
# Home University                    9609
# Other Than Home University         5767
# Home University (Other Than HU)    5322
# State Level                        2809
# Name: count, dtype: int64

# %%
df["status"].value_counts()
# Out:
# status
# Un-Aided                                               16551
# Un-Aided Autonomous                                     2973
# Government                                               713
# Government-Aided Autonomous                              512
# Government Autonomous                                    413
# Un-Aided Autonomous Linguistic Minority - Hindi          369
# Un-Aided Linguistic Minority - Hindi                     321
# University Department                                    251
# Un-Aided Religious Minority - Muslim                     216
# University Autonomous                                    186
# Un-Aided Religious Minority - Christian                  165
# University Managed                                       116
# Deemed University Autonomous                              93
# Un-Aided Autonomous Linguistic Minority - Gujarathi       72
# Un-Aided Religious Minority - Jain                        71
# ...

# %%
df["college_name"].nunique()
# Out:
# 332

# %%
df["branch_name"].nunique()
# Out:
# 80

# %%
df[df["college_name"].isnull()].head(20)
# Out:
# Empty DataFrame
# Columns: [academic_year, college_code, college_name, branch_code, branch_name, status, section, category, stage, merit_rank, percentile]
# Index: []

# %%
df[df["branch_name"].isnull()].head(20)
# Out:
# Empty DataFrame
# Columns: [academic_year, college_code, college_name, branch_code, branch_name, status, section, category, stage, merit_rank, percentile]
# Index: []

# %%
df = pd.read_csv("../dataset/processed/2023-2024.csv")

print(df.shape)
print(df.isnull().sum())
# Out:
# (23507, 11)
# academic_year      0
# college_code       0
# college_name       0
# branch_code        0
# branch_name        0
# status             0
# section            0
# category           0
# stage              0
# merit_rank       495
# percentile       495
# dtype: int64

# %%
df = pd.read_csv("../dataset/processed/2024-2025.csv")

print(df.shape)

print(df.isnull().sum())
# Out:
# (31257, 11)
# academic_year      0
# college_code       0
# college_name       0
# branch_code        0
# branch_name        0
# status             0
# section            0
# category           0
# stage              0
# merit_rank       725
# percentile       725
# dtype: int64

# %%
import pandas as pd

df23 = pd.read_csv("../dataset/processed/2023-2024.csv")
df24 = pd.read_csv("../dataset/processed/2024-2025.csv")
df25 = pd.read_csv("../dataset/processed/2025-2026.csv")

print(df23.shape, df24.shape, df25.shape)
# Out:
# (23507, 11) (31257, 11) (31257, 11)

# %%
print(df23.isnull().sum())
print(df24.isnull().sum())
print(df25.isnull().sum())
# Out:
# academic_year      0
# college_code       0
# college_name       0
# branch_code        0
# branch_name        0
# status             0
# section            0
# category           0
# stage              0
# merit_rank       495
# percentile       495
# dtype: int64
# academic_year      0
# college_code       0
# college_name       0
# branch_code        0
# branch_name        0
# status             0
# section            0
# category           0
# stage              0
# merit_rank       725
# percentile       725
# dtype: int64
# academic_year      0
# college_code       0
# college_name       0
# branch_code        0
# branch_name        0
# status             0
# section            0
# category           0
# stage              0
# merit_rank       725
# percentile       725
# dtype: int64
