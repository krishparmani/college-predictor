# %%
import pandas as pd

# %%
df = pd.read_csv("../dataset/final/cleaned_dataset.csv")

df.shape
# Out:
# (84076, 11)

# %%
import sys
import os

project_root = os.path.abspath("..")

if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from importlib import reload
import src.components.recommendation_engine as rec

reload(rec)

from src.components.recommendation_engine import RecommendationEngine

engine = RecommendationEngine(df)

# %%
engine.df.head()
# Out:
#   academic_year  college_code                                 college_name  \
# 0     2023-2024          1002  Government College of Engineering, Amravati
# 1     2023-2024          1002  Government College of Engineering, Amravati
# 2     2023-2024          1002  Government College of Engineering, Amravati
# 3     2023-2024          1002  Government College of Engineering, Amravati
# 4     2023-2024          1002  Government College of Engineering, Amravati
#
#    branch_code        branch_name                 status          section  \
# 0    100219110  Civil Engineering  Government Autonomous  Home University
# 1    100219110  Civil Engineering  Government Autonomous  Home University
# 2    100219110  Civil Engineering  Government Autonomous  Home University
# 3    100219110  Civil Engineering  Government Autonomous  Home University
# 4    100219110  Civil Engineering  Government Autonomous  Home University
#
#   category stage  merit_rank  percentile
# 0   GOPENS     I       45820   80.732883
# 1     GSCS     I       54803   76.616654
# 2     GSTS     I       85528   58.742985
# 3     GVJS     I       53198   76.921342
# 4    GNT1S     I       55202   76.284368

# %%
branch_df = engine.filter_branch(
    "Computer Engineering"
)

branch_df.head()
# Out:
#     academic_year  college_code                                college_name  \
# 170     2023-2024          1012  Government College of Engineering,Yavatmal
# 171     2023-2024          1012  Government College of Engineering,Yavatmal
# 172     2023-2024          1012  Government College of Engineering,Yavatmal
# 173     2023-2024          1012  Government College of Engineering,Yavatmal
# 174     2023-2024          1012  Government College of Engineering,Yavatmal
#
#      branch_code           branch_name      status          section category  \
# 170    101224510  Computer Engineering  Government  Home University   GOPENH
# 171    101224510  Computer Engineering  Government  Home University     GSCH
# 172    101224510  Computer Engineering  Government  Home University     GSTH
# 173    101224510  Computer Engineering  Government  Home University     GVJH
# 174    101224510  Computer Engineering  Government  Home University    GNT1H
#
#     stage  merit_rank  percentile
# 170     I       31195   87.211312
# 171     I       45916   80.732883
# 172     I       69281   68.933782
# 173     I       31317   87.071832
# 174     I       32367   86.696596

# %%
branch_df.shape
# Out:
# (11642, 11)

# %%
import os

print(os.getcwd())
# Out:
# c:\college predictor\notebook

# %%
import src.logger as lg

print(lg.LOG_FILE_PATH)
# Out:
# c:\college predictor\logs\07_02_2026_23_05_11.log

# %%
branch_df = engine.filter_branch(
    "Computer Engineering"
)

category_df = engine.filter_category(
    branch_df,
    "GOPENH"
)

category_df.shape
# Out:
# (460, 11)

# %%
branch_df = engine.filter_branch(
    "Computer Engineering"
)

category_df = engine.filter_category(
    branch_df,
    "GOPENH"
)

year_df = engine.filter_year(
    category_df,
    "2025-2026"
)

year_df.shape
# Out:
# (159, 11)

# %%
year_df[
    [
        "college_name",
        "branch_name",
        "category",
        "academic_year",
        "percentile"
    ]
].head(10)
# Out:
#                                             college_name  \
# 53763         Government College of Engineering,Yavatmal
# 55508  Manav School of Engineering & Technology, Gut ...
# 57522  Vilasrao Deshmukh Foundation Group of Institut...
# 57599  Aditya Education Trust's Mitthulalji Sarada Po...
# 57642     GRAMIN TECHNICAL AND MANAGEMENT CAMPUS NANDED.
# 57813  STMEI's Sandipani Technical Campus-Faculty of ...
# 58060  Jijau Institute of Engineering Technology and ...
# 58062  Jijau Institute of Engineering Technology and ...
# 58970  Manjara Charitable Trust's Rajiv Gandhi Instit...
# 59222    Thakur Shyamnarayan Engineering College, Mumbai
#
#                 branch_name category academic_year  percentile
# 53763  Computer Engineering   GOPENH     2025-2026   87.129889
# 55508  Computer Engineering   GOPENH     2025-2026   70.872294
# 57522  Computer Engineering   GOPENH     2025-2026   67.844082
# 57599  Computer Engineering   GOPENH     2025-2026   12.562027
# 57642  Computer Engineering   GOPENH     2025-2026   57.253756
# 57813  Computer Engineering   GOPENH     2025-2026   53.769478
# 58060  Computer Engineering   GOPENH     2025-2026    0.492319
# 58062  Computer Engineering   GOPENH     2025-2026   18.702808
# 58970  Computer Engineering   GOPENH     2025-2026   95.715414
# 59222  Computer Engineering   GOPENH     2025-2026   94.782972

# %%
branch_df = engine.filter_branch(
    "Computer Engineering"
)

category_df = engine.filter_category(
    branch_df,
    "GOPENH"
)

year_df = engine.filter_year(
    category_df,
    "2025-2026"
)

year_df.shape
# Out:
# (159, 11)

# %%
year_df[
    [
        "college_name",
        "branch_name",
        "category",
        "academic_year",
        "percentile"
    ]
].head(10)
# Out:
#                                             college_name  \
# 53763         Government College of Engineering,Yavatmal
# 55508  Manav School of Engineering & Technology, Gut ...
# 57522  Vilasrao Deshmukh Foundation Group of Institut...
# 57599  Aditya Education Trust's Mitthulalji Sarada Po...
# 57642     GRAMIN TECHNICAL AND MANAGEMENT CAMPUS NANDED.
# 57813  STMEI's Sandipani Technical Campus-Faculty of ...
# 58060  Jijau Institute of Engineering Technology and ...
# 58062  Jijau Institute of Engineering Technology and ...
# 58970  Manjara Charitable Trust's Rajiv Gandhi Instit...
# 59222    Thakur Shyamnarayan Engineering College, Mumbai
#
#                 branch_name category academic_year  percentile
# 53763  Computer Engineering   GOPENH     2025-2026   87.129889
# 55508  Computer Engineering   GOPENH     2025-2026   70.872294
# 57522  Computer Engineering   GOPENH     2025-2026   67.844082
# 57599  Computer Engineering   GOPENH     2025-2026   12.562027
# 57642  Computer Engineering   GOPENH     2025-2026   57.253756
# 57813  Computer Engineering   GOPENH     2025-2026   53.769478
# 58060  Computer Engineering   GOPENH     2025-2026    0.492319
# 58062  Computer Engineering   GOPENH     2025-2026   18.702808
# 58970  Computer Engineering   GOPENH     2025-2026   95.715414
# 59222  Computer Engineering   GOPENH     2025-2026   94.782972

# %%
classified_df = engine.classify(
    year_df,
    percentile=98.2
)

# %%
classified_df[
    [
        "college_name",
        "percentile",
        "difference",
        "chance"
    ]
].head(20)
# Out:
#                                             college_name  percentile  \
# 53763         Government College of Engineering,Yavatmal   87.129889
# 55508  Manav School of Engineering & Technology, Gut ...   70.872294
# 57522  Vilasrao Deshmukh Foundation Group of Institut...   67.844082
# 57599  Aditya Education Trust's Mitthulalji Sarada Po...   12.562027
# 57642     GRAMIN TECHNICAL AND MANAGEMENT CAMPUS NANDED.   57.253756
# 57813  STMEI's Sandipani Technical Campus-Faculty of ...   53.769478
# 58060  Jijau Institute of Engineering Technology and ...    0.492319
# 58062  Jijau Institute of Engineering Technology and ...   18.702808
# 58970  Manjara Charitable Trust's Rajiv Gandhi Instit...   95.715414
# 59222    Thakur Shyamnarayan Engineering College, Mumbai   94.782972
# 59252  Jawahar Education Society's Annasaheb Chudaman...   88.781302
# 59409  Saraswati Education Society, Yadavrao Tasgaonk...   81.709831
# 59528  Saraswati Education Society's Saraswati Colleg...   90.292154
# 59672  M.G.M.'s College of Engineering and Technology...   87.815228
# 59917  Thadomal Shahani Engineering College, Bandra, ...   98.794695
# 59952  Anjuman-I-Islam's M.H. Saboo Siddik College of...   89.322337
# 60052  N.Y.S.S.'s Datta Meghe College of Engineering,...   92.848822
# 60228  Vasantdada Patil Pratishthan's College Of Engi...   92.848822
# 60348  Bharati Vidyapeeth College of Engineering, Nav...   94.753689
# 60513      Terna Engineering College, Nerul, Navi Mumbai   93.540689
#
#        difference chance
# 53763   11.070111   Safe
# 55508   27.327706   Safe
# 57522   30.355918   Safe
# 57599   85.637973   Safe
# 57642   40.946244   Safe
# 57813   44.430522   Safe
# 58060   97.707681   Safe
# 58062   79.497192   Safe
# 58970    2.484586   Safe
# 59222    3.417028   Safe
# 59252    9.418698   Safe
# 59409   16.490169   Safe
# 59528    7.907846   Safe
# 59672   10.384772   Safe
# 59917   -0.594695  Dream
# 59952    8.877663   Safe
# 60052    5.351178   Safe
# 60228    5.351178   Safe
# 60348    3.446311   Safe
# 60513    4.659311   Safe

# %%
classified_df["chance"].value_counts()
# Out:
# chance
# Safe      157
# Dream       1
# Target      1
# Name: count, dtype: int64

# %%
safe_df = classified_df[
    classified_df["chance"] == "Safe"
]

target_df = classified_df[
    classified_df["chance"] == "Target"
]

dream_df = classified_df[
    classified_df["chance"] == "Dream"
]

# %%
print(len(safe_df))
print(len(target_df))
print(len(dream_df))
# Out:
# 157
# 1
# 1

# %%
from importlib import reload
import src.components.recommendation_engine as rec

reload(rec)

from src.components.recommendation_engine import RecommendationEngine

engine = RecommendationEngine(df)

# %%
result = engine.recommend(
    percentile=98.2,
    category="GOPENH",
    branch="Computer Engineering",
    academic_year="2025-2026"
)

result.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 8
#       1 result = engine.recommend(
#       2     percentile=98.2,
#       3     category="GOPENH",
#       4     branch="Computer Engineering",
#       5     academic_year="2025-2026"
#       6 )
# ----> 8 result.head()
#
# AttributeError: 'dict' object has no attribute 'head'

# %%
from importlib import reload
import src.components.recommendation_engine as rec

reload(rec)

from src.components.recommendation_engine import RecommendationEngine

engine = RecommendationEngine(df)

# %%
result = engine.recommend(
    percentile=98.2,
    category="GOPENH",
    branch="Computer Engineering",
    academic_year="2025-2026"
)

result[
    [
        "college_name",
        "percentile",
        "difference",
        "chance"
    ]
].head(20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 8
#       1 result = engine.recommend(
#       2     percentile=98.2,
#       3     category="GOPENH",
#       4     branch="Computer Engineering",
#       5     academic_year="2025-2026"
#       6 )
# ----> 8 result[
#       9     [
#      10         "college_name",
#      11         "percentile",
#      12         "difference",
#      13         "chance"
#      14     ]
#      15 ].head(20)
#
# TypeError: unhashable type: 'list'

# %%
from importlib import reload
import src.components.recommendation_engine as rec

reload(rec)

from src.components.recommendation_engine import RecommendationEngine

engine = RecommendationEngine(df)

# %%
result = engine.recommend(
    percentile=98.2,
    category="GOPENH",
    branch="Computer Engineering",
    academic_year="2025-2026"
)

# %%
result.keys()
# Out:
# dict_keys(['safe', 'target', 'dream'])

# %%
result["safe"].head()
# Out:
#       academic_year  college_code  \
# 58060     2025-2026          2637
# 82805     2025-2026          6799
# 82801     2025-2026          6799
# 82800     2025-2026          6799
# 57599     2025-2026          2282
#
#                                             college_name  branch_code  \
# 58060  Jijau Institute of Engineering Technology and ...    263724510
# 82805  Shivganga Charitable Trust, Sangli Vishveshwar...    679924510
# 82801  Shivganga Charitable Trust, Sangli Vishveshwar...    679924510
# 82800  Shivganga Charitable Trust, Sangli Vishveshwar...    679924510
# 57599  Aditya Education Trust's Mitthulalji Sarada Po...    228224510
#
#                 branch_name    status                          section  \
# 58060  Computer Engineering  Un-Aided                  Home University
# 82805  Computer Engineering  Un-Aided                      State Level
# 82801  Computer Engineering  Un-Aided  Home University (Other Than HU)
# 82800  Computer Engineering  Un-Aided                  Home University
# 57599  Computer Engineering  Un-Aided                  Home University
#
#       category stage  merit_rank  percentile  difference chance
# 58060   GOPENH     I      179296    0.492319   97.707681   Safe
# 82805   GOPENH     I      176887    3.895894   94.304106   Safe
# 82801   GOPENH     I      175642    5.650827   92.549173   Safe
# 82800   GOPENH     I      173252    8.531383   89.668617   Safe
# 57599   GOPENH     I      169915   12.562027   85.637973   Safe

# %%
result["target"].head()
# Out:
#       academic_year  college_code  \
# 76404     2025-2026          6274
#
#                                             college_name  branch_code  \
# 76404  Pune Vidyarthi Griha's College of Engineering ...    627424510
#
#                 branch_name    status          section category stage  \
# 76404  Computer Engineering  Un-Aided  Home University   GOPENH     I
#
#        merit_rank  percentile  difference  chance
# 76404        6718   97.756002    0.443998  Target

# %%
result["dream"].head()
# Out:
#       academic_year  college_code  \
# 59917     2025-2026          3182
#
#                                             college_name  branch_code  \
# 59917  Thadomal Shahani Engineering College, Bandra, ...    318224510
#
#                 branch_name                                 status  \
# 59917  Computer Engineering  Un-Aided Linguistic Minority - Sindhi
#
#                section category stage  merit_rank  percentile  difference  \
# 59917  Home University   GOPENH     I        3456   98.794695   -0.594695
#
#       chance
# 59917  Dream

# %%
from importlib import reload
import src.components.recommendation_engine as rec

reload(rec)

from src.components.recommendation_engine import RecommendationEngine

engine = RecommendationEngine(df)

# %%
result = engine.recommend(
    percentile=98.2,
    category="GOPENH",
    branch="Computer Engineering",
    academic_year="2025-2026"
)

# %%
len(result["safe"])
len(result["target"])
len(result["dream"])
# Out:
# 1

# %%
safe = result["safe"]

safe.duplicated(
    subset=["college_code", "branch_code"]
).sum()
# Out:
# 0

# %%
from importlib import reload
import src.components.recommendation_engine as rec

reload(rec)

from src.components.recommendation_engine import RecommendationEngine

engine = RecommendationEngine(df)

# %%
result = engine.recommend(
    percentile=98.2,
    category="GOPENH",
    branch="Computer Engineering",
    academic_year="2025-2026"
)

# %%
result["safe"].head()

result["target"].head()

result["dream"].head()
# Out:
#       academic_year  college_code  \
# 59917     2025-2026          3182
#
#                                             college_name  branch_code  \
# 59917  Thadomal Shahani Engineering College, Bandra, ...    318224510
#
#                 branch_name                                 status  \
# 59917  Computer Engineering  Un-Aided Linguistic Minority - Sindhi
#
#                section category stage  merit_rank  percentile  difference  \
# 59917  Home University   GOPENH     I        3456   98.794695   -0.594695
#
#       chance
# 59917  Dream

# %%
from importlib import reload
import src.components.recommendation_engine as rec

reload(rec)

from src.components.recommendation_engine import RecommendationEngine

engine = RecommendationEngine(df)

# %%
result = engine.recommend(
    percentile=98.2,
    category="GOPENH",
    branch="Computer Engineering",
    academic_year="2025-2026"
)

# %%
result["safe"][
    [
        "college_name",
        "difference",
        "confidence"
    ]
].head()
# Out:
#                                             college_name  difference  \
# 82800  Shivganga Charitable Trust, Sangli Vishveshwar...   89.668617
# 57599  Aditya Education Trust's Mitthulalji Sarada Po...   85.637973
# 70612              MKD Institute of Technology, Nadurbar   80.423383
# 58062  Jijau Institute of Engineering Technology and ...   79.497192
# 70349  Maulana Mukhtar Ahmad Nadvi Technical Campus, ...   75.971775
#
#        confidence
# 82800          99
# 57599          99
# 70612          99
# 58062          99
# 70349          99

# %%
from importlib import reload
import src.components.recommendation_engine as rec

reload(rec)

from src.components.recommendation_engine import RecommendationEngine

engine = RecommendationEngine(df)

# %%
result = engine.recommend(
    percentile=98.2,
    category="GOPENH",
    branch="Computer Engineering",
    academic_year="2025-2026"
)

# %%
result["safe"][
    [
        "college_name",
        "difference",
        "confidence"
    ]
].head()
# Out:
#                                             college_name  difference  \
# 82800  Shivganga Charitable Trust, Sangli Vishveshwar...   89.668617
# 57599  Aditya Education Trust's Mitthulalji Sarada Po...   85.637973
# 70612              MKD Institute of Technology, Nadurbar   80.423383
# 58062  Jijau Institute of Engineering Technology and ...   79.497192
# 70349  Maulana Mukhtar Ahmad Nadvi Technical Campus, ...   75.971775
#
#        confidence
# 82800          99
# 57599          99
# 70612          99
# 58062          99
# 70349          99

# %%
result = engine.recommend(
    percentile=98.2,
    category="GOPENH",
    branch="Computer Engineering"
)

# %%
result["safe"][
    [
        "college_name",
        "difference",
        "confidence"
    ]
].head()
# Out:
#                                             college_name  difference  \
# 82800  Shivganga Charitable Trust, Sangli Vishveshwar...   89.668617
# 57599  Aditya Education Trust's Mitthulalji Sarada Po...   85.637973
# 70612              MKD Institute of Technology, Nadurbar   80.423383
# 58062  Jijau Institute of Engineering Technology and ...   79.497192
# 70349  Maulana Mukhtar Ahmad Nadvi Technical Campus, ...   75.971775
#
#        confidence
# 82800          99
# 57599          99
# 70612          99
# 58062          99
# 70349          99

# %%
from importlib import reload
import src.components.recommendation_engine as rec

reload(rec)

from src.components.recommendation_engine import RecommendationEngine

engine = RecommendationEngine(df)

# %%
result = engine.recommend(
    percentile=98.2,
    category="GOPENH",
    branch="Computer Engineering"
)

# %%
result.keys()
# Out:
# dict_keys(['topRecommendation', 'safe', 'target', 'dream'])

# %%
result["topRecommendation"]
# Out:
# academic_year                                            2025-2026
# college_code                                                  6799
# college_name     Shivganga Charitable Trust, Sangli Vishveshwar...
# branch_code                                              679924510
# branch_name                                   Computer Engineering
# status                                                    Un-Aided
# section                                            Home University
# category                                                    GOPENH
# stage                                                            I
# merit_rank                                                  173252
# percentile                                                8.531383
# difference                                               89.668617
# chance                                                        Safe
# confidence                                                      99
# Name: 82800, dtype: object

# %%
from importlib import reload
import src.components.recommendation_engine as rec

reload(rec)

from src.components.recommendation_engine import RecommendationEngine

engine = RecommendationEngine(df)

# %%
result = engine.recommend(
    percentile=98.2,
    category="GOPENH",
    branch="Computer Engineering"
)

# %%
from importlib import reload
import src.components.recommendation_engine as rec

reload(rec)

from src.components.recommendation_engine import RecommendationEngine

engine = RecommendationEngine(df)

# %%
import os

os.makedirs("artifacts", exist_ok=True)

df.to_csv(
    "artifacts/master_dataset.csv",
    index=False
)

print("Dataset saved successfully.")
# Out:
# Dataset saved successfully.

# %%
import os

os.path.exists("artifacts/master_dataset.csv")
# Out:
# True

# %%
import pandas as pd

test = pd.read_csv("artifacts/master_dataset.csv")

print(test.shape)
# Out:
# (84076, 11)

# %%
print(df["category"].unique())
# Out:
# ['GOPENS' 'GSCS' 'GSTS' 'GVJS' 'GNT1S' 'GNT2S' 'GNT3S' 'GOBCS' 'LOPENS'
#  'LSCS' 'LSTS' 'LVJS' 'LNT1S' 'LNT2S' 'LNT3S' 'LOBCS' 'PWDOPENS'
#  'DEFOPENS' 'TFWS' 'EWS' 'PWDROBCS' 'DEFROBCS' 'PWDRSCS' 'GOPENH' 'GSCH'
#  'GVJH' 'GNT1H' 'GOBCH' 'LOPENH' 'LOBCH' 'GOPENO' 'GSCO' 'GNT3O' 'GOBCO'
#  'LOPENO' 'LSCH' 'GSTH' 'GNT2H' 'GNT3H' 'LNT1H' 'LSTH' 'GNT2O' 'LSTO'
#  'LOBCO' 'LNT3H' 'PWDOPENH' 'PWDROBCH' 'GSTO' 'GVJO' 'LSCO' 'LNT2O'
#  'LNT2H' 'LVJO' 'LNT3O' 'LVJH' 'LNT1O' 'GNT1O' 'PWDOBCS' 'DEFOBCS'
#  'DEFRSCS' 'ORPHAN' 'MI' 'DEFRNT3S' 'DEFRNT2S' 'DEFRNT1S' 'DEFRVJS'
#  'PWDRNT2S' 'PWDSCS' 'DEFSCS' 'PWDRNT3S' 'PWDRSCH' 'PWDRNT1S' 'PWDRSTS'
#  'PWDOBCH' 'PWDRNT2H' 'PWDSCH' 'PWDRNT1H' 'PWDRSTH' 'PWDRVJH' 'GSEBCS'
#  'LSEBCS' 'DEFRSEBCS' 'GSEBCH' 'LSEBCH' 'GSEBCO' 'LSEBCO' 'PWDRSEBCS'
#  'DEFSEBCS' 'PWDSEBCS' 'PWDRVJS' 'PWDRSEBCH' 'DEFSTS']
